# %% [markdown]
# <a href="https://colab.research.google.com/github/Santhosh-1801/Computer-Vision-Workshop-FLOXUS/blob/main/Computer_Vision_Workshop_Day_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Numpy:Creation of Arrays
# Matplotlib:Plotting images and data
# Pillow:Opening and visualizing images

# %%
import numpy as np
import matplotlib as m
import PIL

# %%
img=PIL.Image.open('/content/sample_data/dog-and-cat-cover.jpg')

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1200x630 at 0x7F9BB1F758D0>

# %%
image_array=np.array(img)

# %%
image_array
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[251, 251, 251],
#         [251, 251, 251],
#         [251, 251, 251],
#         ...,
#         [251, 251, 251],
#         [251, 251, 251],
#         [251, 251, 251]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
image_array.shape
# Out:
# (630, 1200, 3)

# %%
rot=img.rotate(45)

# %%
rot
# Out:
# <PIL.Image.Image image mode=RGB size=1200x630 at 0x7F9BB0C40C50>

# %%
rotation=img.rotate(90)

# %%
rotation
# Out:
# <PIL.Image.Image image mode=RGB size=1200x630 at 0x7F9BB0C5B210>

# %% [markdown]
# Converting the images to black and white

# %%
img.convert('L')
# Out:
# <PIL.Image.Image image mode=L size=1200x630 at 0x7F9BB0CA0290>

# %%
img.convert('P',palette=PIL.Image.ADAPTIVE,colors=8)
# Out:
# <PIL.Image.Image image mode=P size=1200x630 at 0x7F9BB0B6BC10>

# %%
img.convert('P',palette=PIL.Image.ADAPTIVE,colors=60)
# Out:
# <PIL.Image.Image image mode=P size=1200x630 at 0x7F9BB0D57FD0>

# %% [markdown]
# Resizing the image

# %%
img.resize((400,400))
# Out:
# <PIL.Image.Image image mode=RGB size=400x400 at 0x7F9BB0B6B050>

# %% [markdown]
# Blurring the image

# %%
from PIL import ImageFilter
blurred_image=img.filter(ImageFilter.BLUR)

# %%
blurred_image
# Out:
# <PIL.Image.Image image mode=RGB size=1200x630 at 0x7F9BAF46D4D0>
